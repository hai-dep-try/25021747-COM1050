# %%
#Bai 1
n = int(input(""))
print(2*n)
# Out:
#  4
# 8

# %%
#bai 2
a, b = map(float, input("Nhap chieu dai, chieu rong: ").split())
print(f"Dien tich manh dat trong cay la:{a*b - 3.14*b*b/4:.2f}")
# Out:
# Nhap chieu dai, chieu rong:  12 10
# Dien tich manh dat trong cay la:41.50

# %%
#bai 3
a = input("Nhap chu cai: ")

if a.islower() == True:
    a = a.upper()
    #a = chr(ord(a) + 32)
elif a.islower() == False:
    a = a.lower()
    #a = chr(ord(ch) - 32)
print(a)

'''
if(len(a) == 1):
    if('A' <= a <= 'Z'):
'''
# Out:
# Nhap chu cai:  10
# 10

# %%
#bai 4
a = input("Nhap chu cai: ")

if a.isalpha() == True:
    print(f"{a} la chu cai alphabet")
else:
    print(f"{a} khong la chu cai alphabet")
# Out:
# Nhap chu cai:  10
# 10 khong la chu cai alphabet

# %%
#Bai 5
char = input("Nhap chu hoa: ")

if(char.isupper()):
    if char == "A": 
        print("khong co chu cai o truoc")
    else:
        char = chr(ord(char.lower())-1)
else: print('khong phai chu in hoa')
print(char)
# Out:
# Nhap chu hoa:  a
# khong phai chu in hoa
# a

# %%
a, b, c = map(int, input("Nhap do dai 3 canh: ").split())

if a + b < c or a + c < b or b+c < a:
    print("Khong phai 3 canh cua 1 tam giac")
else:
    p = (a+b+c)/2
    print(f"Dien tich cua tam giac la: {(p*(p-a)*(p-b)*(p-c))**1/2:.1f}")
# Out:
# Nhap do dai 3 canh:  10 12 15
# Dien tich cua tam giac la: 1788.7

# %%
a = input("Nhap chuoi: ")

print(a[4], a[8], a[0])
# Out:
# Nhap chuoi:  ads;lfjsdafs
# l d a

# %%
ten = input("Ten chu ho: ")
thang_truoc = int(input("Chi so thang truoc: ")) 
thang_nay = int(input("Chi so thang nay: ")) 

print(f"Ho va ten: {ten}")

tieu_thu = thang_nay - thang_truoc

if tieu_thu > 0:
    if tieu_thu <= 50: tieu_thu *= 1984
    elif tieu_thu <= 100: tieu_thu = (50 * 1984) + ((tieu_thu - 50) * 2050)
    elif tieu_thu <= 200: tieu_thu = 50 * (1984 + 2050) + (tieu_thu - 100)*2380
    elif tieu_thu <= 300: tieu_thu = 50 * (1984 + 2050) + 100 * 2380 + (tieu_thu - 200)*2998
    elif tieu_thu <= 400: tieu_thu = 50 * (1984 + 2050) + 100 * (2380 + 2998) + (tieu_thu - 300)*3350
    else: tieu_thu = 50 * (1984 + 2050) + 100 * (2380 + 2998 + 3350) + ( tieu_thu - 400) * 3460
'''
if tieu_thu > 400:
    tien += (tieu_thu - 400)*3460
    tieu_thu = 400
if tieu_thu > 300:
    tien += (tieu_thu - 300)*3350
    tieu_thu = 300
if tieu_thu > 200:
    
'''
tien = round(tieu_thu*1.08)
print(f"Tien phai tra la: {tien}")
# Out:
# Ten chu ho:  hai
# Chi so thang truoc:  1020
# Chi so thang nay:  1070
# Ho va ten: hai
# Tien phai tra la: 107136

# %%
#Bài 1
a = int(input())
if a % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
#  4
# Số chẵn

# %%
a = int(input())
if a % 10 == 5:
    print("True")
else:
    print("False")
print("True" if a % 10 == 5 else "False")
# Out:
#  105
# True
# True

# %%
a = int(input())
if a % 3 == 0 and a % 5 == 0:
    print("True")
else:
    print("False")
# Out:
#  45
# True

# %%
y = int(input())
if 2025 - y >= 18:
    print("Đủ tuổi bầu cử")
else:
    print("Không đủ tuổi bầu cử")
# Out:
#  2007
# Đủ tuổi bầu cử

# %%
a, b = map(int, input().split())
if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print("Hai số bằng nhau")
# Out:
#  10 12
# 12

# %%
a = input()

if a.isalpha() == True: print(f"{a} là chữ cái")
elif a.isdigit() == True: print(f"{a} là chữ số")
# Out:
#  10
# 10 là chữ số

# %%
d = float(input())
if d >= 8:
    print("Giỏi")
elif d >= 6.5:
    print("Khá")
elif d >= 5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
#  8.6
# Giỏi

# %%
year = int(input("Nhập năm: "))

if year >= 0:
    if (year % 400 == 0 or year % 4 == 0) and year % 100 != 0:
           print("Nhuận")
    else: print("Không nhuận")
# Out:
# Nhập năm:  1002
# Không nhuận

# %%
x = int(input("Nhập chữ số từ 0 đến 9: "))

match x:
    case 0: print("Không")
    case 1: print("Một")
    case 2: print("Hai")
    case 3: print("Ba")
    case 4: print("Bốn") 
    case 5: print("Năm")
    case 6: print("Sáu")
    case 7: print("Bảy")
    case 8: print("Tám")
    case 9: print("Chín")
# Out:
# Nhập chữ số từ 0 đến 9:  9
# Chín

# %%
d = float(input())
if d >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
#  4.1
# Qua môn

# %%
d = float(input())
if d >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
#  2007
# Qua môn
