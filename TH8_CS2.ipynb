# %%
n = int(input())

Max = 100000
sang = [True] * Max
sang[0] = sang[1] = False
for i in range(2, int(Max**(1/2)) + 1, 1):
    if sang[i] == True:
        for j in range(i*i, Max, i):
            sang[j] = False
#print(sang)
count = 0
for i in range(n + 1):
    if sang[i] == True:
        count += 1
print(count)

'''

count = 0
for i in range(a, b):
    if sang[i] > 2 * i:
        count += 1
print(count)
'''
# Out:
# 4
# '\n\ncount = 0\nfor i in range(a, b):\n    if sang[i] > 2 * i:\n        count += 1\nprint(count)\n'

# %%
n = int(input())
i = 2
while i * i < n:
    while n % i == 0:
        print(i, end = " ")
        n //= i
    i += 1
if n > 1:
    print(n)
# Out:
# 2 2 3 5

# %%
mat_khau = input()

def kiem_tra_mat_khau(mat_khau):
    if len(mat_khau) < 6:
        raise ValueError("Mật khẩu quá ngắn, nhập lại đi!")
    print("Mật khẩu hợp lệ")

print(kiem_tra_mat_khau(mat_khau))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5         raise ValueError("Mật khẩu quá ngắn, nhập lại đi!")
#       6     print("Mật khẩu hợp lệ")
# ----> 8 print(kiem_tra_mat_khau(mat_khau))
#
# Cell In[1], line 5, in kiem_tra_mat_khau(mat_khau)
#       3 def kiem_tra_mat_khau(mat_khau):
#       4     if len(mat_khau) < 6:
# ----> 5         raise ValueError("Mật khẩu quá ngắn, nhập lại đi!")
#       6     print("Mật khẩu hợp lệ")
#
# ValueError: Mật khẩu quá ngắn, nhập lại đi!

# %%
a, b, c, d = map(int, )
# Out:
# 2
