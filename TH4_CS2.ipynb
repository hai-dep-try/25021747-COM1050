# %%
#W4A1
n = int(input())
a = 0
for i in range(n+1):
    a += i
print(a)
# Out:
#  99
# 4851

# %%
#W4A3
n = int(input())
a = 0
for i in range(n):
    a *= i
print(a)

# %%
#W4A4
try:
    n = int(input())

    if n < 0:
        n = -n
    elif n == 0:
        count = 1
    else:
        count = 0
        cs = n
    while(cs > 0):
        cs //= 10
        count += 1
    print(f"So chu so cua n la: {count}")
    
except ValueError:
    print("Nhap so nguyen")
# Out:
#  45
# So chu so cua n la: 2

# %%
#W4A5
n = int(input())
a = []
for i in range(n):
    a.append(int(input()))
    
if 42 in a: 
    print("I've found the meaning of life!")
else: 
    print("It's a joke!")
# Out:
#  4
#  3
#  2
#  42
#  5
# I've found the meaning of life!

# %%
#W4A5
n = int(input())
flag = False
for i in range(n):
    x = int(input())
    if x == 42:
        flag = True
        break
    else: flag = False
if flag is True: print("I've found the meaning of life!")
else: print("It's a joke!")
# Out:
#  3
#  4
#  5
#  42
# I've found the meaning of life!

# %%
def isprime(n):
    if n < 2:
        return False
    for i in range(2, int(n**1/2) + 1):
        if n % i == 0: 
            return False
    return True
try:
    t = int(input())
    for i in range(t):
        a, b = map(int, input().split())
        sum = 0
        for j in range(a, b + 1):
            if (isprime(j) is True): sum += j
        print(f"Tong cac so nguyen to trong doan(a, b) la: {sum}")
except ValueError:
    print("Vui long nhap so nguyen hop le")
# Out:
#  1
#  2 34
# Tong cac so nguyen to trong doan(a, b) la: 160

# %%
def isprime(n):
    if n < 2:
        return False
    for i in range(2, int(n**1/2) + 1):
        if n % i == 0: 
            return False
    return True
try:
    n = int(input())
    for i in range(n, 2, -1):
        if n % i == 0 and isprime(i) is True: 
            print(i)
            break
except ValuError:
    print("Nhap so nguyen duong")
# Out:
#  28
# 7

# %%
def reverse(n):
    a = 0
    while n > 0:
        i = n % 10
        a = a*10 + i
        n //= 10
    return a

def Palidrone(n):
    return n == reverse(n)

n = int(input())
steps = 0
while not Palidrone(n):
    n += reverse(n)
    steps += 1
    if steps > 100: break
    
print(f"Số bước thực hiện: {steps}")
print(f"Giá trị palindrome thu được: {n}")

# %%
#W4A8
n  = int(input(""))
steps = 0

while True:
    s = str(n)
    flag = True
    for i in range(len(s)//2):
        if s[i] != s[len(s)-1-i]:
            flag = False
            break
    rev = 0
    temp = n
    while temp > 0:
        rev = rev * 10 + temp % 10
        temp //= 10
    if rev == n:
        break
    n += rev
    steps += 1
    if steps > 100:
        break

print(steps)
print(n)
# Out:
# 9
# 259727952

# %%
#W4A9
n = int(input())
results =[]
for i in range(1, int(n**0.5) + 1):
    s = str(i**2)
    flag = True
    for j in range(len(s)):
        for x in range(j + 1, len(s)):
            if s[j] == s[x]:
                flag = False
                break
        if not flag:
            break
    if flag:
        results.append(s)
print(results)
# Out:
# ['1', '4', '9', '16', '25', '36', '49', '64', '81']

# %%
#W4A10
n = int(input())
max = 0
x = 0

for i in range(1, n+1):
    temp = i
    steps = 0

    while temp != 1:
        if temp % 2 == 0:
            temp /= 2
        else: 
            temp = temp * 3 + 1
        steps += 1
    if steps > max:
        x = i
        max = steps
print(x, max)
# Out:
# 18 20

# %%
#W4A11
n = int(input())
if n % 2 != 0:
    print(0)
else:
    count = 0
    for i in range(1, int(n**0.5) + 1):
        
        if n % i == 0:
            j = n//i
            if i % 2 == 0:
                count += 1
            if j % 2 == 0 and j != i:
                count += 1
    print(count)
# Out:
# 24

# %%
#W4A12
n = int(input("Nhập số tháng:"))
x = int(input("Nhập số tiền gửi hàng tháng:"))

for i in range(n-1):
    x = x * 1.07 + x
print(x)
# Out:
# 2

# %%
#W4A13
a, b = map(int, input().split())

def uoc(n):
    sum = 0
    for i in range(1, int(n**0.5)):
        if n % i == 0:
            if i != n/i:
                sum += i + n/i
            else: 
                sum += i
    return sum
print(uoc(a), uoc(b))
if uoc(a) ==  uoc(b): 
    print("true")
else:
    print("false")
# Out:
# 504.0 504.0
# true

# %%
#W4A14
a, b = map(int, input().split("Nhap 2 so nguyen duong"))
gcd = 0

'''
brute force
for k in range(1, min(a,b) + 1):
    if a % k == 0 and b % k == 0:
        gcd = k
'''
while b != 0:
    a, b = b, a % b
gcd = a
print(gcd)
# Out:
# 6

# %%
#w4A15
a, b = map(int, input("Tong so con va chan ga, cho:").split())
x = b/2 - a 
y = a - x
# x la cho y la ga
if b % 2 == 0:
    print(f"Co {x} con cho")
    print(f"Co {y} con ga")
else: 
    print("Invalid")
# Out:
# Co 14.0 con cho
# Co 22.0 con ga
