# %%
a, b = map(int, input().split())
def Max_of_true(x, y):
    if x > y: return x
    else: return y
print(Max_of_true(a, b))
# Out:
# 5

# %%
#W5A2 HOAN DOI SO NGUYEN
a, b = map(int, input().split())

def swap(x, y):
    return [y, x]
print(swap(a, b))
# Out:
# [5, 4]

# %%
#W5A3
n = int(input())
'''
if n < 2:
    print(f"{n} ko la snt")
for i in range(2, int(n**(1/2)) + 1):
    if n % i == 0:
        print(f"{n} ko la snt")
        break
else: 
    print(f"{n} la snt")
'''
a = [1]* (n+1)
a[0] = a[1] = 0
for i in range(2, int(n**(1/2)+ 1)):
    if a[i] == 1:
        for j in range(i**2, n + 1, i):
            a[j] = 0
           #print(j)
if a[n] == 1: print("snt")
else: print("ko")
# Out:
# ko

# %%
#W5A4
x = int(input())
import math 
'''
s = 0
for i in range(1, n):
    if n % i == 0:
        s += i
        if i != (n - i) and n % (n - i) == 0:
            s += (n - i)
            print(n-i)
print(s)
if n == s: print(f"{n} la so hoan hao")
else: print(f"{n} ko la so hoan hao")
'''
n = 10**7
a = [1]* (n + 1)
a[0] = a[1] = 0
#sang snt
for i in range(2, int(n**(1/2)+ 1)):
    if a[i] == 1:
        for j in range(i**2, n + 1, i):
            a[j] = 0
def sohoanhao(so):
    for i in range(1, int(math.log2(n)), 1):
        if a[i] == 1:
            tmp1 =  2**i - 1
            if a[tmp1] == 1:
                tmp2 = 2**(i-1)
                #print(tmp1 * tmp2)
                if tmp1 * tmp2 == so:
                    print("so hoan hao")
sohoanhao(x)
# Out:
# so hoan hao

# %%
#W5A5
a = list(map(int, input().split()))
k = int(input())
for i in range(len(a)):
    if a[i] == k:
        print(i)
        break
else: 
    print(-1)
# Out:
# 2

# %%
#W5A6
n = int(input())
def giaithua(so):
    s = 1
    for i in range(1, so + 1):
        #print(i)
        s *= i
    return s
print(giaithua(n))
# Out:
# 120

# %%
x, y = map(int, input().split())
def bit(n):
    if n == 0:
        return "0"
    tmp = ""
    tmp1 = n
    while tmp1 > 0:
        tmp = str(tmp1 % 2) + tmp
        tmp1 = tmp1 // 2
    return tmp
if y < x: x,y = y,x       
print(len(bit(y))-len(bit(x)))
# Out:
# 2

# %%
def chuso(n):
    
    tmp = 0
    while n > 0:
        tmp += n % 10
        n = n // 10
    return tmp

a = int(input())
print(chuso(a))
# Out:
# 20

# %%
s1 = input()
s2 = input()
s1_to_s2 = [None] * 256
s2_to_s1 = [None] * 256
for i in range(len(s1)):
    char1 = s1[i]
    char2 = s2[i]
    if s1_to_s2[ord(s1[i])] is None:
        s1_to_s2[ord(s1[i])] = char2
    elif s1_to_s2[ord(s1[i])] != char2:
        print("False")
        break
    if s2_to_s1[ord(char2)] is None:
        s2_to_s1[ord(char2)] = char1
    # If char2 is already mapped to a different char1, then it's not isomorphic

    elif s2_to_s1[ord(char2)] != char1:
        print("False")
        break
else:
    print("True") # This line should be outside the loop, after the loop finishes without breaking

'''
def isIsomorphic(s1: str, s2: str) -> bool:
    if len(s1) != len(s2):
        return False

    # Use lists of size 256 to simulate character mappings,
    # as dictionaries (map structure) are not allowed.
    # Initialize with None to indicate no mapping yet.
    map_s1_to_s2 = [None] * 256
    map_s2_to_s1 = [None] * 256

    for i in range(len(s1)):
        char1 = s1[i]
        char2 = s2[i]
        ord_char1 = ord(char1)
        ord_char2 = ord(char2)

        # Check mapping from s1 to s2
        # If no mapping exists for char1 yet
        if map_s1_to_s2[ord_char1] is None:
            map_s1_to_s2[ord_char1] = char2
        elif map_s1_to_s2[ord_char1] != char2:
            return False

        # Check mapping from s2 to s1 (ensures unique reverse mapping)
        if map_s2_to_s1[ord_char2] is None:
            map_s2_to_s1[ord_char2] = char1
        elif map_s2_to_s1[ord_char2] != char1:
            return False

    return True
print(isIsomorphic(s1, s2))
'''
# Out:
# True
# ...
